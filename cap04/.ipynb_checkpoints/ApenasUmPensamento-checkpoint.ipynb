# %% [markdown]
# # Aprendendo um novo caminho para fazer dados soltos se transformarem em caminhos para decisões!
# ## Cada novo desafio vencido eleva o nível
# ### Cada nível vencido aumenta seu valor para o mercado como solucionador de problemas
# #### Lembre-se que o seu valor é medido mais que apenas números, só lembre de que números são muito importantes!
